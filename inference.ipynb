# %%
import cv2
import torch
import json
from ultralytics import YOLO
from datetime import timedelta
import argparse
import time
import os


video_path= 'C:/Users/alex_dextop/PycharmProjects/Yolo_2/rem.mp4'      # путь к видеофайлу
MODEL_PATH = 'yolov8n.pt'          # путь к твоей модели
OUTPUT_JSON = 'violations_report.json'
VIOLATION_CLASSES = {
    0: 'No_Helmet',
    1: 'No_Vest',
    2: 'Unsafe_Position',
    # Добавь свои классы если нужно
}
model = YOLO(MODEL_PATH)
cap = cv2.VideoCapture(video_path)
fps = cap.get(cv2.CAP_PROP_FPS)
interval = 5  # секунд

results_by_interval = []
frame_num = 0
current_interval_start = 0
interval_violations = []



def save_interval_result(start_frame, detected_violations):
    if not detected_violations:
        return None
    # Сгруппируем классы и объекты
    grouped = {}
    for item in detected_violations:
        key = (item['violation_class'], tuple(item['detected_objects']))
        grouped.setdefault(key, []).append(item)

    result = []
    for (vcls, dobjs), group in grouped.items():
        result.append({
            "violation_class": vcls,
            "number": '',  # Место для распознавания номеров
            "frame": group[0]['frame'],
            "time": f"{group[0]['time']}",
            "detected_objects": list(dobjs),
            "violation_type": "Safety",
            "count": len(group)
        })
    return result







class YOLOv8PersonDetector:
    def __init__(self, model_path='yolov8n.pt', conf_threshold=0.5):
        """
        Инициализация детектора
        
        Args:
            model_path (str): Путь к модели YOLOv8
            conf_threshold (float): Порог уверенности для детекции
        """
        self.conf_threshold = conf_threshold
        
        # Загрузка модели
        print("Загрузка модели YOLOv8...")
        self.model = YOLO(model_path)
        print("Модель загружена успешно!")
        
        # Проверяем наличие GPU
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print(f"Используется устройство: {self.device}")
        
    def process_video(self, video_path, output_path=None, show_video=True):
        """
        Обработка видео и обнаружение людей
        
        Args:
            video_path (str): Путь к входному видео
            output_path (str): Путь для сохранения результата (опционально)
            show_video (bool): Показывать ли видео в реальном времени
        """
        # Открываем видео
        # cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Ошибка: Не удалось открыть видео {video_path}")
            return
        
        # Получаем параметры видео
        fps = cap.get(cv2.CAP_PROP_FPS)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        
        print(f"Параметры видео: {width}x{height}, FPS: {fps:.2f}, Кадров: {total_frames}")
        
        # Настройка видео writer для сохранения результата
        if output_path:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        
        frame_count = 0
        start_time = time.time()
        
        print("Начинаем обработку видео...")
        
        while True:
            ret, frame = cap.read()
            cv2.line(frame, (750, 715), (625, 170), (0, 0, 255), 2, 2)

            if not ret:
                break

            frame_num += 1
            time_in_sec = frame_num / fps 
            if time_in_sec >= current_interval_start + interval:
                v = save_interval_result(current_interval_start, interval_violations)
                if v:
                    results_by_interval.extend(v)
                interval_violations = []
                current_interval_start += interval
            results = model(frame)[0]

            for det in results.boxes.data.tolist():
                    x1, y1, x2, y2, conf, cls_id = det
                    cls_id = int(cls_id)
                    violation_class = VIOLATION_CLASSES.get(cls_id, f'class_{cls_id}')
                    objects = ['person'] if violation_class.startswith('No_') or violation_class == 'Unsafe_Position' else []
                    time_str = str(timedelta(seconds=int(time_in_sec)))
                    violation = {
                        "violation_class": violation_class,
                        "number": "",  # номер можно дописать если появится модуль чтения номеров
                        "frame": frame_num,
                        "time": time_str,
                        "detected_objects": objects,
                        "violation_type": "Safety"
                    }
                    interval_violations.append(violation)
            v = save_interval_result(current_interval_start, interval_violations)
            if v:
                results_by_interval.extend(v)



            # Детекция людей на кадре
            results = self.model(frame, conf=self.conf_threshold, classes=[0])  # class 0 = person
            
            # Отрисовка результатов
            annotated_frame = self.draw_detections(frame, results)
            
            # Отображение информации
            annotated_frame = self.display_info(annotated_frame, frame_count, fps)
            
            # Сохранение результата
            if output_path:
                out.write(annotated_frame)
            
            # Показ видео
            if show_video:
                cv2.imshow('YOLOv8 Person Detection', annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            
            frame_count += 1
            
            # Вывод прогресса каждые 100 кадров
            if frame_count % 100 == 0:
                elapsed_time = time.time() - start_time
                print(f"Обработано кадров: {frame_count}/{total_frames} "f"({frame_count/elapsed_time:.2f} FPS)")
        
        # Освобождение ресурсов
        cap.release()
        if output_path:
            out.release()
        cv2.destroyAllWindows()
        
        total_time = time.time() - start_time
        print(f"Обработка завершена!")
        print(f"Всего кадров: {frame_count}")
        print(f"Общее время: {total_time:.2f} сек")
        print(f"Средняя скорость: {frame_count/total_time:.2f} FPS")
    
    def draw_detections(self, frame, results):
        """
        Отрисовка bounding boxes и меток на кадре
        """
        for result in results:
            boxes = result.boxes
            if boxes is not None:
                for box in boxes:
                    # Координаты bounding box
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    conf = box.conf[0].item()
                    class_id = int(box.cls[0])
                    
                    # Рисуем bounding box
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Добавляем метку с уверенностью
                    label = f"Person: {conf:.2f}"
                    label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)[0]
                    
                    # Фон для текста
                    cv2.rectangle(frame, (x1, y1 - label_size[1] - 10), (x1 + label_size[0], y1), (0, 255, 0), -1)
                    
                    # Текст
                    cv2.putText(frame, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 2)
        
        return frame
    
    def display_info(self, frame, frame_count, fps):
        """
        Отображение информации на кадре
        """
        info_text = f"Frame: {frame_count} | FPS: {fps:.1f}"
        cv2.putText(frame, info_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        return frame

def main():
    parser = argparse.ArgumentParser(description='YOLOv8 Person Detection on Video')
    parser.add_argument('--video', type=str, required=True, help='Path to input video')
    parser.add_argument('--output', type=str, default='output.mp4', help='Path to output video')
    parser.add_argument('--model', type=str, default='yolov8m.pt', help='Path to YOLOv8 model')
    parser.add_argument('--conf', type=float, default=0.5, help='Confidence threshold')
    parser.add_argument('--no-show', action='store_true', help='Do not show video during processing')
    
    args = parser.parse_args()
    
    # Проверка существования видеофайла
    if not os.path.exists(args.video):
        print(f"Ошибка: Видеофайл {args.video} не найден!")
        return
    
    # Создание детектора
    detector = YOLOv8PersonDetector(model_path=args.model, conf_threshold=args.conf)
    
    # Обработка видео
    detector.process_video(
        video_path=args.video,
        output_path=args.output,
        show_video=not args.no_show
    )

# Простой вариант использования без аргументов командной строки
def simple_example():
    """
    Простой пример использования без аргументов командной строки
    """
    # video_path = "C:/Users/alex_dextop/PycharmProjects/Yolo_2/remont_1.mp4"  # Укажите путь к вашему видео
    output_path = "detected_people.mp4"
    
    # Проверка существования файла
    if not os.path.exists(video_path):
        print(f"Видеофайл {video_path} не найден!")
        print("Пожалуйста, укажите правильный путь к видеофайлу")
        return
    
    # Создание детектора
    detector = YOLOv8PersonDetector(model_path='yolov8m.pt', conf_threshold=0.5)
    
    # Обработка видео
    detector.process_video(
        video_path=video_path,
        output_path=output_path,
        show_video=True
    )

with open(OUTPUT_JSON, "w", encoding="utf-8") as f:
    json.dump(results_by_interval, f, ensure_ascii=False, indent=4)

print(f"Сохранено {len(results_by_interval)} записей о нарушениях в {OUTPUT_JSON}")

if __name__ == "__main__":
    # Использование с аргументами командной строки
    # main()
    
    # Или простой вариант (раскомментируйте нужный)
    simple_example()
# Out:
# Сохранено 0 записей о нарушениях в violations_report.json
# Загрузка модели YOLOv8...
# Модель загружена успешно!
# Используется устройство: cpu
# Параметры видео: 1280x720, FPS: 29.97, Кадров: 315
# Начинаем обработку видео...
# ---------------------------------------------------------------------------
# UnboundLocalError                         Traceback (most recent call last)
# Cell In[16], line 284
#     277 print(f"Сохранено {len(results_by_interval)} записей о нарушениях в {OUTPUT_JSON}")
#     279 if __name__ == "__main__":
#     280     # Использование с аргументами командной строки
#     281     # main()
#     282
#     283     # Или простой вариант (раскомментируйте нужный)
# --> 284     simple_example()
#
# Cell In[16], line 268, in simple_example()
#     265 detector = YOLOv8PersonDetector(model_path='yolov8m.pt', conf_threshold=0.5)
#     267 # Обработка видео
# --> 268 detector.process_video(
#     269     video_path=video_path,
#     270     output_path=output_path,
#     271     show_video=True
#     272 )
#
# Cell In[16], line 120, in YOLOv8PersonDetector.process_video(self, video_path, output_path, show_video)
#     117 if not ret:
#     118     break
# --> 120 frame_num += 1
#     121 time_in_sec = frame_num / fps
#     122 if time_in_sec >= current_interval_start + interval:
#
# UnboundLocalError: cannot access local variable 'frame_num' where it is not associated with a value

# %%
import cv2
import torch
from ultralytics import YOLO
import argparse
import time
import os
import sort

class YOLOv8PersonDetector:
    def __init__(self, model_path='yolov8n.pt', conf_threshold=0.5):
        """
        Инициализация детектора
        
        Args:
            model_path (str): Путь к модели YOLOv8
            conf_threshold (float): Порог уверенности для детекции
        """
        self.conf_threshold = conf_threshold
        
        # Загрузка модели
        print("Загрузка модели YOLOv8...")
        self.model = YOLO(model_path)
        print("Модель загружена успешно!")
        
        # Проверяем наличие GPU
        self.device = 'cuda' if torch.cuda.is_available() else 'cpu'
        print(f"Используется устройство: {self.device}")
        # self.tracker = sort.Sort()
        
    def process_video(self, video_path, output_path=None, show_video=True):
        """
        Обработка видео и обнаружение людей
        
        Args:
            video_path (str): Путь к входному видео
            output_path (str): Путь для сохранения результата (опционально)
            show_video (bool): Показывать ли видео в реальном времени
        """
        # Открываем видео
        cap = cv2.VideoCapture(video_path)
        if not cap.isOpened():
            print(f"Ошибка: Не удалось открыть видео {video_path}")
            return
        
        # Получаем параметры видео
        fps = cap.get(cv2.CAP_PROP_FPS)
        width = int(cap.get(cv2.CAP_PROP_FRAME_WIDTH))
        height = int(cap.get(cv2.CAP_PROP_FRAME_HEIGHT))
        total_frames = int(cap.get(cv2.CAP_PROP_FRAME_COUNT))
        
        print(f"Параметры видео: {width}x{height}, FPS: {fps:.2f}, Кадров: {total_frames}")
        
        # Настройка видео writer для сохранения результата
        if output_path:
            fourcc = cv2.VideoWriter_fourcc(*'mp4v')
            out = cv2.VideoWriter(output_path, fourcc, fps, (width, height))
        
        frame_count = 0
        start_time = time.time()
        
        print("Начинаем обработку видео...")
        
        while True:
            ret, frame = cap.read()
            cv2.line(frame, (750, 715), (625, 170), (0, 0, 255), 2, 2)
            if not ret:
                break
            
            # Детекция людей на кадре
            results = self.model(frame, conf=self.conf_threshold, classes=[0])  # class 0 = person
            
            # Отрисовка результатов
            annotated_frame = self.draw_detections(frame, results)
            
            # Отображение информации
            annotated_frame = self.display_info(annotated_frame, frame_count, fps)

            # Сохранение результата
            if output_path:
                out.write(annotated_frame)
            
            # Показ видео
            if show_video:
                cv2.imshow('YOLOv8 Person Detection', annotated_frame)
                if cv2.waitKey(1) & 0xFF == ord('q'):
                    break
            
            frame_count += 1
            
            # Вывод прогресса каждые 10 кадров
            if frame_count % 1000 == 0:
                elapsed_time = time.time() - start_time
                print(f"Обработано кадров: {frame_count}/{total_frames} "  f"({frame_count/elapsed_time:.2f} FPS)")
        
        # Освобождение ресурсов
        cap.release()
        if output_path:
            out.release()
        cv2.destroyAllWindows()
        
        total_time = time.time() - start_time
        print(f"Обработка завершена!")
        print(f"Всего кадров: {frame_count}")
        print(f"Общее время: {total_time:.2f} сек")
        print(f"Средняя скорость: {frame_count/total_time:.2f} FPS")
    
    def draw_detections(self, frame, results):
        """
        Отрисовка bounding boxes и меток на кадре
        """
        for result in results:
            boxes = result.boxes
            if boxes is not None:
                for box in boxes:
                    # Координаты bounding box
                    x1, y1, x2, y2 = map(int, box.xyxy[0])
                    conf = box.conf[0].item()
                    class_id = int(box.cls[0])
                    
                    # Рисуем bounding box
                    cv2.rectangle(frame, (x1, y1), (x2, y2), (0, 255, 0), 2)
                    
                    # Добавляем метку с уверенностью
                    label = f"Person: {conf:.2f}"
                    label_size = cv2.getTextSize(label, cv2.FONT_HERSHEY_SIMPLEX, 0.6, 2)[0]
                    
                    # Фон для текста
                    cv2.rectangle(frame, (x1, y1 - label_size[1] - 10), (x1 + label_size[0], y1), (0, 255, 0), -1)
                    
                    # Текст
                    cv2.putText(frame, label, (x1, y1 - 5), cv2.FONT_HERSHEY_SIMPLEX, 0.6, (0, 0, 0), 2)
        
        return frame
    
    def display_info(self, frame, frame_count, fps):
        """
        Отображение информации на кадре
        """
        info_text = f"Frame: {frame_count} | FPS: {fps:.1f}"
        cv2.putText(frame, info_text, (10, 30), cv2.FONT_HERSHEY_SIMPLEX, 1, (255, 255, 255), 2)
        return frame

def main():
    parser = argparse.ArgumentParser(description='YOLOv8 Person Detection on Video')
    parser.add_argument('--video', type=str, required=True, help='Path to input video')
    parser.add_argument('--output', type=str, default='output.mp4', help='Path to output video')
    parser.add_argument('--model', type=str, default='yolov8m.pt', help='Path to YOLOv8 model')
    parser.add_argument('--conf', type=float, default=0.5, help='Confidence threshold')
    parser.add_argument('--no-show', action='store_true', help='Do not show video during processing')
    
    args = parser.parse_args()
    
    # Проверка существования видеофайла
    if not os.path.exists(args.video):
        print(f"Ошибка: Видеофайл {args.video} не найден!")
        return
    
    # Создание детектора
    detector = YOLOv8PersonDetector(model_path=args.model, conf_threshold=args.conf)
    
    # Обработка видео
    detector.process_video(
        video_path=args.video,
        output_path=args.output,
        show_video=not args.no_show
    )
# v = sort.save_interval_result(current_interval_start, interval_violations)
# print(v)
# Простой вариант использования без аргументов командной строки
def simple_example():
    """
    Простой пример использования без аргументов командной строки
    """
    video_path = "C:/Users/alex_dextop/PycharmProjects/Yolo_2/remont_30.mp4"  # Укажите путь к вашему видео
    output_path = "remont_1.mp4"
    
    # Проверка существования файла
    if not os.path.exists(video_path):
        print(f"Видеофайл {video_path} не найден!")
        print("Пожалуйста, укажите правильный путь к видеофайлу")
        return
    
    # Создание детектора
    detector = YOLOv8PersonDetector(model_path='yolov8m.pt', conf_threshold=0.5)
    
    # Обработка видео
    detector.process_video(
        video_path=video_path,
        output_path=output_path,
        show_video=True
    )
if __name__ == "__main__":
    # Использование с аргументами командной строки
    # main()
    
    # Или простой вариант (раскомментируйте нужный)
    simple_example()
# Out:
# Загрузка модели YOLOv8...
# Модель загружена успешно!
# Используется устройство: cpu
# Параметры видео: 1280x720, FPS: 29.97, Кадров: 886
# Начинаем обработку видео...
#
# 0: 384x640 3 persons, 207.9ms
# Speed: 1.7ms preprocess, 207.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 224.1ms
# Speed: 1.6ms preprocess, 224.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.8ms
# Speed: 1.2ms preprocess, 199.8ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.5ms
# Speed: 1.5ms preprocess, 191.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.7ms
# Speed: 1.3ms preprocess, 187.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.7ms
# Speed: 1.4ms preprocess, 193.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 137.5ms
# Speed: 1.2ms preprocess, 137.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.3ms
# Speed: 2.0ms preprocess, 188.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.5ms
# Speed: 1.5ms preprocess, 191.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.7ms
# Speed: 1.4ms preprocess, 188.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 183.5ms
# Speed: 1.3ms preprocess, 183.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.7ms
# Speed: 1.7ms preprocess, 188.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 186.9ms
# Speed: 1.7ms preprocess, 186.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 174.0ms
# Speed: 1.7ms preprocess, 174.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.6ms
# Speed: 1.4ms preprocess, 193.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.5ms
# Speed: 1.3ms preprocess, 193.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.1ms
# Speed: 1.5ms preprocess, 191.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.4ms
# Speed: 1.8ms preprocess, 190.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 189.3ms
# Speed: 1.2ms preprocess, 189.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.0ms
# Speed: 1.5ms preprocess, 194.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.9ms
# Speed: 1.2ms preprocess, 187.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.2ms
# Speed: 1.4ms preprocess, 191.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.0ms
# Speed: 1.9ms preprocess, 187.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.6ms
# Speed: 1.8ms preprocess, 188.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.5ms
# Speed: 1.4ms preprocess, 195.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.4ms
# Speed: 1.6ms preprocess, 197.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.4ms
# Speed: 1.2ms preprocess, 194.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.3ms
# Speed: 1.6ms preprocess, 204.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.4ms
# Speed: 1.9ms preprocess, 192.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.3ms
# Speed: 1.2ms preprocess, 194.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.3ms
# Speed: 1.4ms preprocess, 193.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.8ms
# Speed: 1.3ms preprocess, 190.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.3ms
# Speed: 1.7ms preprocess, 190.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 184.8ms
# Speed: 1.8ms preprocess, 184.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.1ms
# Speed: 2.1ms preprocess, 197.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.7ms
# Speed: 1.8ms preprocess, 194.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.0ms
# Speed: 1.9ms preprocess, 188.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 168.8ms
# Speed: 1.5ms preprocess, 168.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 177.2ms
# Speed: 2.0ms preprocess, 177.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.0ms
# Speed: 2.4ms preprocess, 193.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.6ms
# Speed: 1.4ms preprocess, 200.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 181.7ms
# Speed: 1.3ms preprocess, 181.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.5ms
# Speed: 1.5ms preprocess, 188.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.2ms
# Speed: 2.0ms preprocess, 187.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.4ms
# Speed: 1.5ms preprocess, 197.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.7ms
# Speed: 1.6ms preprocess, 193.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.8ms
# Speed: 1.4ms preprocess, 203.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 189.1ms
# Speed: 2.0ms preprocess, 189.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 186.5ms
# Speed: 1.2ms preprocess, 186.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.6ms
# Speed: 1.5ms preprocess, 191.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.1ms
# Speed: 1.3ms preprocess, 190.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.0ms
# Speed: 1.5ms preprocess, 193.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 186.7ms
# Speed: 1.6ms preprocess, 186.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.1ms
# Speed: 1.8ms preprocess, 204.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 217.3ms
# Speed: 2.0ms preprocess, 217.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.7ms
# Speed: 1.5ms preprocess, 202.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 181.5ms
# Speed: 1.7ms preprocess, 181.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 184.6ms
# Speed: 1.5ms preprocess, 184.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.8ms
# Speed: 1.3ms preprocess, 193.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.0ms
# Speed: 1.2ms preprocess, 190.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.8ms
# Speed: 1.5ms preprocess, 197.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 185.7ms
# Speed: 1.2ms preprocess, 185.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.6ms
# Speed: 1.5ms preprocess, 191.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.7ms
# Speed: 1.5ms preprocess, 196.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.1ms
# Speed: 1.5ms preprocess, 197.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.2ms
# Speed: 1.1ms preprocess, 190.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 160.2ms
# Speed: 2.0ms preprocess, 160.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.2ms
# Speed: 1.4ms preprocess, 187.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.7ms
# Speed: 1.4ms preprocess, 200.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.3ms
# Speed: 1.3ms preprocess, 188.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 165.4ms
# Speed: 1.3ms preprocess, 165.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 189.8ms
# Speed: 1.3ms preprocess, 189.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.9ms
# Speed: 1.5ms preprocess, 191.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.0ms
# Speed: 2.2ms preprocess, 190.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 172.7ms
# Speed: 1.4ms preprocess, 172.7ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.2ms
# Speed: 1.6ms preprocess, 200.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.3ms
# Speed: 1.9ms preprocess, 199.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.0ms
# Speed: 1.2ms preprocess, 198.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.5ms
# Speed: 1.2ms preprocess, 193.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.7ms
# Speed: 1.4ms preprocess, 199.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.5ms
# Speed: 1.2ms preprocess, 199.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 218.6ms
# Speed: 2.2ms preprocess, 218.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.6ms
# Speed: 1.7ms preprocess, 195.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.4ms
# Speed: 1.3ms preprocess, 198.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 179.5ms
# Speed: 1.3ms preprocess, 179.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.4ms
# Speed: 1.3ms preprocess, 192.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.1ms
# Speed: 1.4ms preprocess, 195.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.6ms
# Speed: 1.4ms preprocess, 200.6ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.9ms
# Speed: 2.0ms preprocess, 199.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.6ms
# Speed: 1.8ms preprocess, 199.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 165.0ms
# Speed: 1.6ms preprocess, 165.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.3ms
# Speed: 1.5ms preprocess, 191.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.4ms
# Speed: 1.7ms preprocess, 209.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 215.2ms
# Speed: 1.7ms preprocess, 215.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.0ms
# Speed: 1.3ms preprocess, 209.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 181.2ms
# Speed: 1.6ms preprocess, 181.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 170.9ms
# Speed: 1.9ms preprocess, 170.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.1ms
# Speed: 1.4ms preprocess, 194.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.2ms
# Speed: 1.5ms preprocess, 194.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.5ms
# Speed: 1.3ms preprocess, 195.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.4ms
# Speed: 2.1ms preprocess, 190.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.0ms
# Speed: 1.2ms preprocess, 197.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.5ms
# Speed: 1.6ms preprocess, 192.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.0ms
# Speed: 1.2ms preprocess, 192.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.0ms
# Speed: 1.5ms preprocess, 196.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.6ms
# Speed: 1.5ms preprocess, 191.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.8ms
# Speed: 1.4ms preprocess, 190.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.4ms
# Speed: 1.2ms preprocess, 190.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 211.1ms
# Speed: 1.6ms preprocess, 211.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.5ms
# Speed: 1.4ms preprocess, 198.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 183.1ms
# Speed: 1.7ms preprocess, 183.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.3ms
# Speed: 2.2ms preprocess, 201.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 159.3ms
# Speed: 1.5ms preprocess, 159.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.6ms
# Speed: 1.5ms preprocess, 193.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 186.7ms
# Speed: 1.4ms preprocess, 186.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 204.4ms
# Speed: 1.4ms preprocess, 204.4ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.0ms
# Speed: 1.6ms preprocess, 198.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.0ms
# Speed: 1.9ms preprocess, 193.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.5ms
# Speed: 1.6ms preprocess, 208.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.4ms
# Speed: 1.7ms preprocess, 200.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.3ms
# Speed: 1.2ms preprocess, 200.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 184.0ms
# Speed: 1.5ms preprocess, 184.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.8ms
# Speed: 2.0ms preprocess, 195.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.2ms
# Speed: 1.4ms preprocess, 199.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.4ms
# Speed: 1.2ms preprocess, 200.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.0ms
# Speed: 1.6ms preprocess, 195.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.4ms
# Speed: 1.3ms preprocess, 204.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.3ms
# Speed: 1.3ms preprocess, 204.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.6ms
# Speed: 1.2ms preprocess, 207.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.5ms
# Speed: 1.2ms preprocess, 193.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.4ms
# Speed: 1.6ms preprocess, 193.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.8ms
# Speed: 1.7ms preprocess, 192.8ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.0ms
# Speed: 2.1ms preprocess, 194.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 182.2ms
# Speed: 1.3ms preprocess, 182.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.3ms
# Speed: 1.8ms preprocess, 191.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 211.0ms
# Speed: 1.6ms preprocess, 211.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.7ms
# Speed: 1.5ms preprocess, 197.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 165.8ms
# Speed: 1.4ms preprocess, 165.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 174.7ms
# Speed: 1.5ms preprocess, 174.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.5ms
# Speed: 1.4ms preprocess, 199.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.9ms
# Speed: 1.4ms preprocess, 194.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.3ms
# Speed: 1.2ms preprocess, 198.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.4ms
# Speed: 1.6ms preprocess, 199.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.7ms
# Speed: 2.0ms preprocess, 187.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 212.4ms
# Speed: 1.3ms preprocess, 212.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.5ms
# Speed: 1.3ms preprocess, 194.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.2ms
# Speed: 1.5ms preprocess, 193.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.1ms
# Speed: 1.4ms preprocess, 201.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.7ms
# Speed: 1.3ms preprocess, 190.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 184.2ms
# Speed: 1.3ms preprocess, 184.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.3ms
# Speed: 2.0ms preprocess, 199.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.7ms
# Speed: 1.7ms preprocess, 209.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.6ms
# Speed: 1.6ms preprocess, 198.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 202.5ms
# Speed: 1.5ms preprocess, 202.5ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 139.0ms
# Speed: 1.5ms preprocess, 139.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 174.4ms
# Speed: 1.5ms preprocess, 174.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.2ms
# Speed: 1.9ms preprocess, 206.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.9ms
# Speed: 1.6ms preprocess, 204.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.5ms
# Speed: 1.8ms preprocess, 204.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.8ms
# Speed: 1.7ms preprocess, 197.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.6ms
# Speed: 1.4ms preprocess, 190.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.7ms
# Speed: 1.9ms preprocess, 199.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.9ms
# Speed: 3.2ms preprocess, 192.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.0ms
# Speed: 1.6ms preprocess, 196.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.3ms
# Speed: 1.4ms preprocess, 198.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.2ms
# Speed: 1.9ms preprocess, 203.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.2ms
# Speed: 1.3ms preprocess, 190.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.4ms
# Speed: 1.3ms preprocess, 191.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 179.9ms
# Speed: 2.0ms preprocess, 179.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.2ms
# Speed: 1.5ms preprocess, 197.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.8ms
# Speed: 1.7ms preprocess, 203.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 212.8ms
# Speed: 1.3ms preprocess, 212.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.5ms
# Speed: 1.3ms preprocess, 188.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.3ms
# Speed: 1.9ms preprocess, 197.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.9ms
# Speed: 1.3ms preprocess, 199.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.4ms
# Speed: 1.5ms preprocess, 201.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.1ms
# Speed: 1.2ms preprocess, 197.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.7ms
# Speed: 1.8ms preprocess, 203.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.4ms
# Speed: 1.4ms preprocess, 206.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.6ms
# Speed: 1.5ms preprocess, 205.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.9ms
# Speed: 1.3ms preprocess, 197.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.3ms
# Speed: 1.6ms preprocess, 200.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.5ms
# Speed: 1.8ms preprocess, 192.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.9ms
# Speed: 1.5ms preprocess, 204.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.9ms
# Speed: 1.2ms preprocess, 203.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 182.4ms
# Speed: 1.5ms preprocess, 182.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.6ms
# Speed: 1.8ms preprocess, 196.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.9ms
# Speed: 1.5ms preprocess, 193.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 221.5ms
# Speed: 1.5ms preprocess, 221.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 201.0ms
# Speed: 1.3ms preprocess, 201.0ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.2ms
# Speed: 1.7ms preprocess, 205.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 200.3ms
# Speed: 1.7ms preprocess, 200.3ms inference, 1.0ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 173.2ms
# Speed: 1.5ms preprocess, 173.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 205.3ms
# Speed: 1.5ms preprocess, 205.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 170.1ms
# Speed: 1.5ms preprocess, 170.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.2ms
# Speed: 1.8ms preprocess, 202.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.8ms
# Speed: 1.4ms preprocess, 202.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.2ms
# Speed: 1.8ms preprocess, 200.2ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 210.6ms
# Speed: 1.8ms preprocess, 210.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.9ms
# Speed: 1.5ms preprocess, 206.9ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.8ms
# Speed: 1.4ms preprocess, 204.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 2 persons, 196.0ms
# Speed: 2.2ms preprocess, 196.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.5ms
# Speed: 1.2ms preprocess, 204.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.0ms
# Speed: 1.7ms preprocess, 199.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.5ms
# Speed: 1.9ms preprocess, 195.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.7ms
# Speed: 1.4ms preprocess, 194.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.5ms
# Speed: 1.7ms preprocess, 205.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 189.3ms
# Speed: 1.8ms preprocess, 189.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.4ms
# Speed: 1.4ms preprocess, 203.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.1ms
# Speed: 1.6ms preprocess, 190.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.7ms
# Speed: 1.5ms preprocess, 202.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.8ms
# Speed: 1.4ms preprocess, 191.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.8ms
# Speed: 1.4ms preprocess, 193.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 216.6ms
# Speed: 1.9ms preprocess, 216.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 169.8ms
# Speed: 1.7ms preprocess, 169.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.5ms
# Speed: 1.3ms preprocess, 194.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.1ms
# Speed: 1.4ms preprocess, 201.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.3ms
# Speed: 1.3ms preprocess, 198.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.1ms
# Speed: 1.4ms preprocess, 202.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 210.8ms
# Speed: 1.7ms preprocess, 210.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.4ms
# Speed: 1.5ms preprocess, 202.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.4ms
# Speed: 1.5ms preprocess, 202.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 210.3ms
# Speed: 1.3ms preprocess, 210.3ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.7ms
# Speed: 1.8ms preprocess, 209.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.4ms
# Speed: 1.8ms preprocess, 203.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.7ms
# Speed: 1.8ms preprocess, 200.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 213.1ms
# Speed: 1.8ms preprocess, 213.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.3ms
# Speed: 1.4ms preprocess, 205.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 214.3ms
# Speed: 1.4ms preprocess, 214.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.8ms
# Speed: 1.4ms preprocess, 207.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 214.1ms
# Speed: 1.7ms preprocess, 214.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.6ms
# Speed: 1.6ms preprocess, 209.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 222.1ms
# Speed: 1.7ms preprocess, 222.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.6ms
# Speed: 1.9ms preprocess, 201.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.7ms
# Speed: 1.2ms preprocess, 192.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.3ms
# Speed: 1.2ms preprocess, 208.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.6ms
# Speed: 1.6ms preprocess, 199.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.2ms
# Speed: 1.7ms preprocess, 204.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.8ms
# Speed: 1.6ms preprocess, 199.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.5ms
# Speed: 1.4ms preprocess, 201.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 219.9ms
# Speed: 1.3ms preprocess, 219.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.1ms
# Speed: 2.0ms preprocess, 193.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.5ms
# Speed: 1.3ms preprocess, 195.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.0ms
# Speed: 1.7ms preprocess, 196.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.2ms
# Speed: 1.5ms preprocess, 195.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.9ms
# Speed: 1.3ms preprocess, 200.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.3ms
# Speed: 1.3ms preprocess, 205.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.9ms
# Speed: 1.3ms preprocess, 202.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.8ms
# Speed: 1.4ms preprocess, 197.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.7ms
# Speed: 1.4ms preprocess, 208.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.2ms
# Speed: 1.8ms preprocess, 197.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 171.9ms
# Speed: 1.3ms preprocess, 171.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 184.7ms
# Speed: 1.4ms preprocess, 184.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.6ms
# Speed: 1.7ms preprocess, 195.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.7ms
# Speed: 1.3ms preprocess, 187.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.3ms
# Speed: 2.0ms preprocess, 197.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 172.5ms
# Speed: 1.7ms preprocess, 172.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.5ms
# Speed: 1.7ms preprocess, 196.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.4ms
# Speed: 1.4ms preprocess, 207.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.2ms
# Speed: 1.3ms preprocess, 192.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.0ms
# Speed: 1.6ms preprocess, 199.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.4ms
# Speed: 1.4ms preprocess, 191.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.6ms
# Speed: 1.3ms preprocess, 192.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.6ms
# Speed: 1.4ms preprocess, 198.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.6ms
# Speed: 1.4ms preprocess, 208.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 219.0ms
# Speed: 1.4ms preprocess, 219.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.6ms
# Speed: 1.4ms preprocess, 193.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 174.8ms
# Speed: 1.4ms preprocess, 174.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.1ms
# Speed: 1.9ms preprocess, 201.1ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 190.5ms
# Speed: 1.7ms preprocess, 190.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 188.3ms
# Speed: 1.7ms preprocess, 188.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.0ms
# Speed: 1.5ms preprocess, 202.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.7ms
# Speed: 1.3ms preprocess, 199.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.8ms
# Speed: 1.5ms preprocess, 204.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.2ms
# Speed: 1.8ms preprocess, 201.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.6ms
# Speed: 1.3ms preprocess, 200.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.5ms
# Speed: 1.9ms preprocess, 194.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.6ms
# Speed: 1.6ms preprocess, 195.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.2ms
# Speed: 1.2ms preprocess, 205.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.0ms
# Speed: 1.6ms preprocess, 201.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.0ms
# Speed: 1.4ms preprocess, 197.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.7ms
# Speed: 1.5ms preprocess, 200.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.4ms
# Speed: 1.3ms preprocess, 205.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.8ms
# Speed: 1.6ms preprocess, 201.8ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 210.9ms
# Speed: 1.8ms preprocess, 210.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.3ms
# Speed: 1.3ms preprocess, 200.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.0ms
# Speed: 1.5ms preprocess, 200.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.3ms
# Speed: 1.7ms preprocess, 201.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.4ms
# Speed: 1.8ms preprocess, 206.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 187.9ms
# Speed: 1.4ms preprocess, 187.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 225.4ms
# Speed: 1.5ms preprocess, 225.4ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 229.0ms
# Speed: 1.3ms preprocess, 229.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 169.9ms
# Speed: 1.4ms preprocess, 169.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.9ms
# Speed: 1.5ms preprocess, 198.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.6ms
# Speed: 1.4ms preprocess, 194.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.1ms
# Speed: 1.5ms preprocess, 209.1ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.8ms
# Speed: 1.8ms preprocess, 197.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.6ms
# Speed: 1.6ms preprocess, 206.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.4ms
# Speed: 1.4ms preprocess, 207.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 211.4ms
# Speed: 1.7ms preprocess, 211.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 216.1ms
# Speed: 1.5ms preprocess, 216.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.7ms
# Speed: 2.0ms preprocess, 206.7ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.5ms
# Speed: 1.8ms preprocess, 200.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.8ms
# Speed: 2.0ms preprocess, 205.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.3ms
# Speed: 1.2ms preprocess, 198.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 191.7ms
# Speed: 1.9ms preprocess, 191.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 213.0ms
# Speed: 1.9ms preprocess, 213.0ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.7ms
# Speed: 2.1ms preprocess, 209.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.5ms
# Speed: 1.3ms preprocess, 207.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.1ms
# Speed: 1.6ms preprocess, 209.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.7ms
# Speed: 2.0ms preprocess, 208.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.9ms
# Speed: 1.5ms preprocess, 204.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 212.1ms
# Speed: 1.3ms preprocess, 212.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.7ms
# Speed: 1.7ms preprocess, 203.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.3ms
# Speed: 1.3ms preprocess, 208.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 215.3ms
# Speed: 2.0ms preprocess, 215.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.3ms
# Speed: 1.7ms preprocess, 200.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 174.9ms
# Speed: 1.3ms preprocess, 174.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.0ms
# Speed: 1.5ms preprocess, 197.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.2ms
# Speed: 1.7ms preprocess, 201.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.9ms
# Speed: 1.7ms preprocess, 198.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.3ms
# Speed: 1.7ms preprocess, 203.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.5ms
# Speed: 2.1ms preprocess, 199.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.7ms
# Speed: 1.5ms preprocess, 205.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.8ms
# Speed: 1.4ms preprocess, 202.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.6ms
# Speed: 1.6ms preprocess, 195.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.3ms
# Speed: 1.3ms preprocess, 202.3ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.3ms
# Speed: 1.8ms preprocess, 203.3ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.6ms
# Speed: 1.2ms preprocess, 197.6ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.6ms
# Speed: 2.1ms preprocess, 208.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 189.8ms
# Speed: 1.3ms preprocess, 189.8ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.5ms
# Speed: 1.8ms preprocess, 202.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.2ms
# Speed: 1.3ms preprocess, 192.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.9ms
# Speed: 1.5ms preprocess, 201.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.4ms
# Speed: 1.3ms preprocess, 206.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.4ms
# Speed: 1.5ms preprocess, 194.4ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.9ms
# Speed: 1.9ms preprocess, 201.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.9ms
# Speed: 1.7ms preprocess, 206.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 184.5ms
# Speed: 1.6ms preprocess, 184.5ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.4ms
# Speed: 1.7ms preprocess, 200.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.1ms
# Speed: 1.5ms preprocess, 198.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 225.5ms
# Speed: 1.3ms preprocess, 225.5ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.2ms
# Speed: 1.4ms preprocess, 204.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.7ms
# Speed: 1.4ms preprocess, 203.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 171.4ms
# Speed: 1.8ms preprocess, 171.4ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.0ms
# Speed: 1.8ms preprocess, 201.0ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 173.5ms
# Speed: 1.6ms preprocess, 173.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.5ms
# Speed: 1.5ms preprocess, 197.5ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.7ms
# Speed: 1.4ms preprocess, 203.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.0ms
# Speed: 1.5ms preprocess, 197.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.8ms
# Speed: 1.3ms preprocess, 204.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.1ms
# Speed: 1.3ms preprocess, 194.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.3ms
# Speed: 1.8ms preprocess, 207.3ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 171.5ms
# Speed: 1.7ms preprocess, 171.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.1ms
# Speed: 1.3ms preprocess, 197.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.1ms
# Speed: 1.5ms preprocess, 197.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.4ms
# Speed: 1.6ms preprocess, 208.4ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.7ms
# Speed: 2.2ms preprocess, 200.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 183.2ms
# Speed: 1.6ms preprocess, 183.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.9ms
# Speed: 1.5ms preprocess, 199.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.7ms
# Speed: 1.5ms preprocess, 194.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.0ms
# Speed: 1.5ms preprocess, 199.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.7ms
# Speed: 1.8ms preprocess, 206.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.8ms
# Speed: 1.9ms preprocess, 193.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.9ms
# Speed: 1.6ms preprocess, 197.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.1ms
# Speed: 1.9ms preprocess, 200.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.6ms
# Speed: 2.2ms preprocess, 194.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 210.7ms
# Speed: 1.6ms preprocess, 210.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.2ms
# Speed: 1.6ms preprocess, 196.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.3ms
# Speed: 1.5ms preprocess, 208.3ms inference, 1.8ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.1ms
# Speed: 1.5ms preprocess, 203.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 214.1ms
# Speed: 1.6ms preprocess, 214.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.6ms
# Speed: 1.6ms preprocess, 202.6ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.7ms
# Speed: 1.3ms preprocess, 206.7ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.9ms
# Speed: 1.8ms preprocess, 200.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.6ms
# Speed: 2.0ms preprocess, 201.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.1ms
# Speed: 1.6ms preprocess, 201.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.2ms
# Speed: 1.7ms preprocess, 207.2ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.2ms
# Speed: 1.5ms preprocess, 200.2ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.5ms
# Speed: 1.4ms preprocess, 203.5ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.4ms
# Speed: 2.0ms preprocess, 207.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.7ms
# Speed: 1.5ms preprocess, 198.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.8ms
# Speed: 1.5ms preprocess, 199.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.7ms
# Speed: 1.8ms preprocess, 197.7ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.1ms
# Speed: 1.4ms preprocess, 205.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.0ms
# Speed: 1.5ms preprocess, 199.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.2ms
# Speed: 1.5ms preprocess, 195.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.9ms
# Speed: 1.5ms preprocess, 200.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.5ms
# Speed: 1.3ms preprocess, 201.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 220.0ms
# Speed: 1.2ms preprocess, 220.0ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 209.0ms
# Speed: 1.3ms preprocess, 209.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 194.4ms
# Speed: 1.8ms preprocess, 194.4ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.6ms
# Speed: 1.9ms preprocess, 197.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.7ms
# Speed: 1.3ms preprocess, 201.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.7ms
# Speed: 1.6ms preprocess, 206.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 166.9ms
# Speed: 1.5ms preprocess, 166.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.3ms
# Speed: 1.5ms preprocess, 198.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.8ms
# Speed: 1.2ms preprocess, 199.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.1ms
# Speed: 1.5ms preprocess, 201.1ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.4ms
# Speed: 1.2ms preprocess, 203.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.0ms
# Speed: 1.6ms preprocess, 203.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.9ms
# Speed: 1.5ms preprocess, 199.9ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 148.2ms
# Speed: 1.9ms preprocess, 148.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 215.3ms
# Speed: 1.6ms preprocess, 215.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 175.8ms
# Speed: 1.8ms preprocess, 175.8ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.5ms
# Speed: 1.4ms preprocess, 199.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.2ms
# Speed: 1.3ms preprocess, 197.2ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 184.5ms
# Speed: 1.5ms preprocess, 184.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 179.9ms
# Speed: 1.7ms preprocess, 179.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.5ms
# Speed: 1.8ms preprocess, 195.5ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.9ms
# Speed: 1.5ms preprocess, 199.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 201.8ms
# Speed: 1.3ms preprocess, 201.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 211.6ms
# Speed: 1.6ms preprocess, 211.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 219.9ms
# Speed: 1.8ms preprocess, 219.9ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.3ms
# Speed: 1.3ms preprocess, 204.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 189.0ms
# Speed: 1.3ms preprocess, 189.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.9ms
# Speed: 1.4ms preprocess, 200.9ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 211.6ms
# Speed: 1.7ms preprocess, 211.6ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 167.2ms
# Speed: 1.4ms preprocess, 167.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 211.2ms
# Speed: 1.6ms preprocess, 211.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 200.4ms
# Speed: 1.8ms preprocess, 200.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.4ms
# Speed: 1.3ms preprocess, 192.4ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 205.6ms
# Speed: 2.2ms preprocess, 205.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 198.0ms
# Speed: 1.5ms preprocess, 198.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.9ms
# Speed: 2.1ms preprocess, 197.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.3ms
# Speed: 2.5ms preprocess, 204.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.2ms
# Speed: 1.5ms preprocess, 208.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.6ms
# Speed: 1.4ms preprocess, 206.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.6ms
# Speed: 1.4ms preprocess, 196.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 192.3ms
# Speed: 1.5ms preprocess, 192.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 195.6ms
# Speed: 1.3ms preprocess, 195.6ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.1ms
# Speed: 1.3ms preprocess, 197.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.3ms
# Speed: 1.8ms preprocess, 193.3ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 186.7ms
# Speed: 1.5ms preprocess, 186.7ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 185.6ms
# Speed: 1.2ms preprocess, 185.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.2ms
# Speed: 1.4ms preprocess, 197.2ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.2ms
# Speed: 1.2ms preprocess, 208.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 212.9ms
# Speed: 1.6ms preprocess, 212.9ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 197.1ms
# Speed: 1.4ms preprocess, 197.1ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 213.2ms
# Speed: 1.6ms preprocess, 213.2ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 206.7ms
# Speed: 1.3ms preprocess, 206.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 204.8ms
# Speed: 1.3ms preprocess, 204.8ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 216.0ms
# Speed: 1.4ms preprocess, 216.0ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 214.0ms
# Speed: 2.0ms preprocess, 214.0ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 203.6ms
# Speed: 1.7ms preprocess, 203.6ms inference, 1.5ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 215.9ms
# Speed: 1.6ms preprocess, 215.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 208.4ms
# Speed: 2.1ms preprocess, 208.4ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 212.1ms
# Speed: 1.3ms preprocess, 212.1ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 199.7ms
# Speed: 1.2ms preprocess, 199.7ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 207.9ms
# Speed: 1.7ms preprocess, 207.9ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 210.3ms
# Speed: 1.6ms preprocess, 210.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 199.3ms
# Speed: 1.7ms preprocess, 199.3ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 195.6ms
# Speed: 1.5ms preprocess, 195.6ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 196.7ms
# Speed: 1.5ms preprocess, 196.7ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 225.6ms
# Speed: 2.0ms preprocess, 225.6ms inference, 1.2ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 193.5ms
# Speed: 1.3ms preprocess, 193.5ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 3 persons, 202.1ms
# Speed: 1.4ms preprocess, 202.1ms inference, 1.1ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 208.0ms
# Speed: 1.6ms preprocess, 208.0ms inference, 1.4ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 208.3ms
# Speed: 1.3ms preprocess, 208.3ms inference, 1.6ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 196.9ms
# Speed: 1.7ms preprocess, 196.9ms inference, 1.7ms postprocess per image at shape (1, 3, 384, 640)
#
# 0: 384x640 4 persons, 197.8ms
# Speed: 1.8ms preprocess, 197.8ms inference, 1.3ms postprocess per image at shape (1, 3, 384, 640)
# Обработка завершена!
# Всего кадров: 461
# Общее время: 98.73 сек
# Средняя скорость: 4.67 FPS

# %% [markdown]
# Трекинг лишь на класс птица:
